# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("train.csv")
data.drop(columns=["PassengerId", "Name", "Ticket"], inplace=True)
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
data["Sex"] = data["Sex"].map({"male": 0, "female": 1})
data.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    0  22.0      1      0   7.2500   NaN        S
# 1         1       1    1  38.0      1      0  71.2833   C85        C
# 2         1       3    1  26.0      0      0   7.9250   NaN        S
# 3         1       1    1  35.0      1      0  53.1000  C123        S
# 4         0       3    0  35.0      0      0   8.0500   NaN        S

# %%
cabin_nans = data["Cabin"].isna()
cabin_nans = cabin_nans.map({True: 0, False: 1})
data["Cabin"] = cabin_nans
data.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Cabin Embarked
# 0         0       3    0  22.0      1      0   7.2500      0        S
# 1         1       1    1  38.0      1      0  71.2833      1        C
# 2         1       3    1  26.0      0      0   7.9250      0        S
# 3         1       1    1  35.0      1      0  53.1000      1        S
# 4         0       3    0  35.0      0      0   8.0500      0        S

# %%
def correlation(data):
  corrmat = data.corr()
  top_corr_features = corrmat.index
  plt.figure(figsize=(15,15))
  g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")

correlation(data)

# %%
men = data[data["Sex"] == 0]
women = data[data["Sex"] == 1]

print(men["Survived"].sum() / len(men))
print(women["Survived"].sum() / len(women))
# Out:
# 0.18890814558058924
# 0.7420382165605095
