# %%
from cgi import test
import pandas as pd
import math
from sklearn.metrics import mean_absolute_error, mean_squared_log_error
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from xgboost import XGBRegressor

data = pd.read_csv("train.csv")
#features = ["LotArea", "OverallQual", "OverallCond", "YearBuilt", "YearRemodAdd", "TotalBsmtSF", "GrLivArea", "1stFlrSF", "2ndFlrSF", "GarageArea", "PoolArea", "YrSold"]
#X = data[features]
#y = data["SalePrice"]
X = data.drop(columns="SalePrice")
y = data.SalePrice

numerical_cols = [col for col in X.columns if X[col].dtype in ["int64", "float64"]]
categorical_cols = [col for col in X.columns if X[col].dtype == "object"]

X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2)

# %%
numerical_transformer = SimpleImputer()
categorical_transformer = Pipeline(
  steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown="ignore")),
  ]
)

preprocessor = ColumnTransformer(
  transformers=[
    ("num", numerical_transformer, numerical_cols),
    ("cat", categorical_transformer, categorical_cols)
  ]
)

my_pipeline = Pipeline(
  steps=[
    ("preprocessor", preprocessor),
    ("model", XGBRegressor(n_estimators=1000, learning_rate=0.03, early_stopping_rounds=5, eval_metric=mean_squared_log_error))
  ]
)
# Out:
# 'scores = -1 * cross_val_score(my_pipeline, X, y, cv=5, scoring="neg_mean_squared_log_error")\nfor i in range(len(scores)):\n  scores[i] = math.sqrt(scores[i])\nprint(scores.mean())'

# %%
X_test = pd.read_csv("test.csv")

#my_pipeline.fit(X, y)
#predictions = my_pipeline.predict(X_test)
X_valid_transformed = preprocessor.fit_transform(X_valid)

my_pipeline.fit(X_train, y_train, model__eval_set=[(X_valid_transformed, y_valid)])
predictions = my_pipeline.predict(X_valid)
score = math.sqrt(mean_squared_log_error(y_valid, predictions))
print(score)
# Out:
# [0]	validation_0-rmse:196156.08211	validation_0-mean_squared_log_error:16.79468
# [1]	validation_0-rmse:191260.06962	validation_0-mean_squared_log_error:10.63656
# [2]	validation_0-rmse:187117.36621	validation_0-mean_squared_log_error:8.53834
# [3]	validation_0-rmse:183257.09881	validation_0-mean_squared_log_error:7.01300
# [4]	validation_0-rmse:178707.16942	validation_0-mean_squared_log_error:5.60353
# [5]	validation_0-rmse:174610.91658	validation_0-mean_squared_log_error:4.66036
# [6]	validation_0-rmse:170653.27853	validation_0-mean_squared_log_error:3.89624
# [7]	validation_0-rmse:166795.18812	validation_0-mean_squared_log_error:3.32032
# [8]	validation_0-rmse:162686.76611	validation_0-mean_squared_log_error:2.85567
# [9]	validation_0-rmse:158996.54228	validation_0-mean_squared_log_error:2.51387
# [10]	validation_0-rmse:155497.06546	validation_0-mean_squared_log_error:2.23707
# [11]	validation_0-rmse:151672.67459	validation_0-mean_squared_log_error:1.97077
# [12]	validation_0-rmse:148619.08580	validation_0-mean_squared_log_error:1.79370
# [13]	validation_0-rmse:145608.00234	validation_0-mean_squared_log_error:1.63611
# [14]	validation_0-rmse:142311.61139	validation_0-mean_squared_log_error:1.48713
# [15]	validation_0-rmse:139617.70293	validation_0-mean_squared_log_error:1.36822
# [16]	validation_0-rmse:136510.55479	validation_0-mean_squared_log_error:1.25645
# [17]	validation_0-rmse:133253.63607	validation_0-mean_squared_log_error:1.14435
# [18]	validation_0-rmse:130450.10287	validation_0-mean_squared_log_error:1.05590
# [19]	validation_0-rmse:127883.76989	validation_0-mean_squared_log_error:0.98216
# [20]	validation_0-rmse:125482.28474	validation_0-mean_squared_log_error:0.92139
# [21]	validation_0-rmse:123001.36448	validation_0-mean_squared_log_error:0.86628
# [22]	validation_0-rmse:120600.41546	validation_0-mean_squared_log_error:0.80559
# [23]	validation_0-rmse:118403.02541	validation_0-mean_squared_log_error:0.76134
# [24]	validation_0-rmse:116341.48167	validation_0-mean_squared_log_error:0.71555
# [25]	validation_0-rmse:114122.73479	validation_0-mean_squared_log_error:0.66676
# [26]	validation_0-rmse:111842.17564	validation_0-mean_squared_log_error:0.62184
# [27]	validation_0-rmse:109875.43678	validation_0-mean_squared_log_error:0.58964
# [28]	validation_0-rmse:107873.47108	validation_0-mean_squared_log_error:0.55586
# [29]	validation_0-rmse:106152.73328	validation_0-mean_squared_log_error:0.53029
# [30]	validation_0-rmse:104432.08713	validation_0-mean_squared_log_error:0.50813
# [31]	validation_0-rmse:102570.24946	validation_0-mean_squared_log_error:0.47897
# [32]	validation_0-rmse:100616.20441	validation_0-mean_squared_log_error:0.44965
# [33]	validation_0-rmse:99150.48486	validation_0-mean_squared_log_error:0.43122
# [34]	validation_0-rmse:97360.85558	validation_0-mean_squared_log_error:0.40792
# [35]	validation_0-rmse:95915.42240	validation_0-mean_squared_log_error:0.39267
# [36]	validation_0-rmse:94103.12578	validation_0-mean_squared_log_error:0.37137
# [37]	validation_0-rmse:92384.03907	validation_0-mean_squared_log_error:0.35229
# [38]	validation_0-rmse:91189.80950	validation_0-mean_squared_log_error:0.33787
# [39]	validation_0-rmse:89766.82081	validation_0-mean_squared_log_error:0.32191
# [40]	validation_0-rmse:88293.51466	validation_0-mean_squared_log_error:0.30792
# [41]	validation_0-rmse:86996.13189	validation_0-mean_squared_log_error:0.29611
# [42]	validation_0-rmse:85499.41787	validation_0-mean_squared_log_error:0.28249
# [43]	validation_0-rmse:84018.46359	validation_0-mean_squared_log_error:0.26890
# [44]	validation_0-rmse:82656.24606	validation_0-mean_squared_log_error:0.25719
# [45]	validation_0-rmse:81586.44338	validation_0-mean_squared_log_error:0.24842
# [46]	validation_0-rmse:80224.90629	validation_0-mean_squared_log_error:0.23777
# [47]	validation_0-rmse:79079.64144	validation_0-mean_squared_log_error:0.22913
# [48]	validation_0-rmse:77951.32364	validation_0-mean_squared_log_error:0.22043
# [49]	validation_0-rmse:76923.59698	validation_0-mean_squared_log_error:0.21273
# [50]	validation_0-rmse:76000.46784	validation_0-mean_squared_log_error:0.20521
# [51]	validation_0-rmse:74953.69899	validation_0-mean_squared_log_error:0.19679
# [52]	validation_0-rmse:74052.77152	validation_0-mean_squared_log_error:0.19049
# [53]	validation_0-rmse:73050.23054	validation_0-mean_squared_log_error:0.18278
# [54]	validation_0-rmse:72028.52576	validation_0-mean_squared_log_error:0.17593
# [55]	validation_0-rmse:71144.39215	validation_0-mean_squared_log_error:0.17009
# [56]	validation_0-rmse:70230.16162	validation_0-mean_squared_log_error:0.16448
# [57]	validation_0-rmse:69419.59100	validation_0-mean_squared_log_error:0.15923
# [58]	validation_0-rmse:68579.10891	validation_0-mean_squared_log_error:0.15401
# [59]	validation_0-rmse:67837.42700	validation_0-mean_squared_log_error:0.14956
# [60]	validation_0-rmse:66891.47355	validation_0-mean_squared_log_error:0.14395
# [61]	validation_0-rmse:66118.51504	validation_0-mean_squared_log_error:0.13962
# [62]	validation_0-rmse:65449.25625	validation_0-mean_squared_log_error:0.13605
# [63]	validation_0-rmse:64771.30837	validation_0-mean_squared_log_error:0.13209
# [64]	validation_0-rmse:64096.62198	validation_0-mean_squared_log_error:0.12820
# [65]	validation_0-rmse:63515.31531	validation_0-mean_squared_log_error:0.12520
# [66]	validation_0-rmse:62920.21820	validation_0-mean_squared_log_error:0.12220
# [67]	validation_0-rmse:62110.87664	validation_0-mean_squared_log_error:0.11744
# [68]	validation_0-rmse:61379.18838	validation_0-mean_squared_log_error:0.11319
# [69]	validation_0-rmse:60709.79218	validation_0-mean_squared_log_error:0.10957
# [70]	validation_0-rmse:60167.46535	validation_0-mean_squared_log_error:0.10703
# [71]	validation_0-rmse:59605.60343	validation_0-mean_squared_log_error:0.10453
# [72]	validation_0-rmse:59017.46553	validation_0-mean_squared_log_error:0.10182
# [73]	validation_0-rmse:58424.20267	validation_0-mean_squared_log_error:0.09919
# [74]	validation_0-rmse:57892.03684	validation_0-mean_squared_log_error:0.09716
# [75]	validation_0-rmse:57218.19490	validation_0-mean_squared_log_error:0.09346
# [76]	validation_0-rmse:56561.61754	validation_0-mean_squared_log_error:0.08994
# [77]	validation_0-rmse:55952.45696	validation_0-mean_squared_log_error:0.08687
# [78]	validation_0-rmse:55373.54525	validation_0-mean_squared_log_error:0.08385
# [79]	validation_0-rmse:55044.48558	validation_0-mean_squared_log_error:0.08206
# [80]	validation_0-rmse:54525.09824	validation_0-mean_squared_log_error:0.07952
# [81]	validation_0-rmse:54104.03223	validation_0-mean_squared_log_error:0.07777
# [82]	validation_0-rmse:53760.80093	validation_0-mean_squared_log_error:0.07608
# [83]	validation_0-rmse:53246.34053	validation_0-mean_squared_log_error:0.07408
# [84]	validation_0-rmse:52751.97008	validation_0-mean_squared_log_error:0.07224
# [85]	validation_0-rmse:52516.82781	validation_0-mean_squared_log_error:0.07147
# [86]	validation_0-rmse:52143.65286	validation_0-mean_squared_log_error:0.06923
# [87]	validation_0-rmse:51892.56254	validation_0-mean_squared_log_error:0.06835
# [88]	validation_0-rmse:51863.41738	validation_0-mean_squared_log_error:0.06856
# [89]	validation_0-rmse:51556.90992	validation_0-mean_squared_log_error:0.06732
# [90]	validation_0-rmse:51533.73221	validation_0-mean_squared_log_error:0.06754
# [91]	validation_0-rmse:51219.74402	validation_0-mean_squared_log_error:0.06570
# [92]	validation_0-rmse:51004.30149	validation_0-mean_squared_log_error:0.06496
# [93]	validation_0-rmse:50717.29413	validation_0-mean_squared_log_error:0.06331
# [94]	validation_0-rmse:50276.23793	validation_0-mean_squared_log_error:0.06153
# [95]	validation_0-rmse:50282.52544	validation_0-mean_squared_log_error:0.06186
# [96]	validation_0-rmse:50072.63537	validation_0-mean_squared_log_error:0.06076
# [97]	validation_0-rmse:49816.61395	validation_0-mean_squared_log_error:0.05974
# [98]	validation_0-rmse:49432.51470	validation_0-mean_squared_log_error:0.05828
# [99]	validation_0-rmse:49308.72951	validation_0-mean_squared_log_error:0.05786
# [100]	validation_0-rmse:49331.42239	validation_0-mean_squared_log_error:0.05823
# [101]	validation_0-rmse:49070.00098	validation_0-mean_squared_log_error:0.05742
# [102]	validation_0-rmse:47843.68162	validation_0-mean_squared_log_error:0.05208
# [103]	validation_0-rmse:47688.93368	validation_0-mean_squared_log_error:0.05158
# [104]	validation_0-rmse:46571.22070	validation_0-mean_squared_log_error:0.04712
# [105]	validation_0-rmse:45536.44559	validation_0-mean_squared_log_error:0.04333
# [106]	validation_0-rmse:45242.37624	validation_0-mean_squared_log_error:0.04259
# [107]	validation_0-rmse:45016.01663	validation_0-mean_squared_log_error:0.04207
# [108]	validation_0-rmse:44113.66272	validation_0-mean_squared_log_error:0.03910
# [109]	validation_0-rmse:43956.16387	validation_0-mean_squared_log_error:0.03890
# [110]	validation_0-rmse:43859.20302	validation_0-mean_squared_log_error:0.03874
# [111]	validation_0-rmse:43659.21052	validation_0-mean_squared_log_error:0.03817
# [112]	validation_0-rmse:43481.39222	validation_0-mean_squared_log_error:0.03775
# [113]	validation_0-rmse:43303.24892	validation_0-mean_squared_log_error:0.03729
# [114]	validation_0-rmse:43173.26294	validation_0-mean_squared_log_error:0.03716
# [115]	validation_0-rmse:43020.85537	validation_0-mean_squared_log_error:0.03688
# [116]	validation_0-rmse:42818.91974	validation_0-mean_squared_log_error:0.03647
# [117]	validation_0-rmse:42630.87984	validation_0-mean_squared_log_error:0.03603
# [118]	validation_0-rmse:42441.48409	validation_0-mean_squared_log_error:0.03574
# [119]	validation_0-rmse:42275.61763	validation_0-mean_squared_log_error:0.03535
# [120]	validation_0-rmse:42078.52572	validation_0-mean_squared_log_error:0.03495
# [121]	validation_0-rmse:41894.68602	validation_0-mean_squared_log_error:0.03472
# [122]	validation_0-rmse:41751.82169	validation_0-mean_squared_log_error:0.03450
# [123]	validation_0-rmse:41619.35901	validation_0-mean_squared_log_error:0.03430
# [124]	validation_0-rmse:41482.29080	validation_0-mean_squared_log_error:0.03404
# [125]	validation_0-rmse:41310.17785	validation_0-mean_squared_log_error:0.03381
# [126]	validation_0-rmse:41197.16864	validation_0-mean_squared_log_error:0.03362
# [127]	validation_0-rmse:41054.61108	validation_0-mean_squared_log_error:0.03335
# [128]	validation_0-rmse:40919.99442	validation_0-mean_squared_log_error:0.03306
# [129]	validation_0-rmse:40741.76912	validation_0-mean_squared_log_error:0.03274
# [130]	validation_0-rmse:40610.65053	validation_0-mean_squared_log_error:0.03259
# [131]	validation_0-rmse:40482.89093	validation_0-mean_squared_log_error:0.03232
# [132]	validation_0-rmse:40321.51514	validation_0-mean_squared_log_error:0.03205
# [133]	validation_0-rmse:40185.97180	validation_0-mean_squared_log_error:0.03189
# [134]	validation_0-rmse:40060.53188	validation_0-mean_squared_log_error:0.03174
# [135]	validation_0-rmse:39908.71761	validation_0-mean_squared_log_error:0.03149
# [136]	validation_0-rmse:39784.14032	validation_0-mean_squared_log_error:0.03135
# [137]	validation_0-rmse:39663.96649	validation_0-mean_squared_log_error:0.03113
# [138]	validation_0-rmse:39544.91570	validation_0-mean_squared_log_error:0.03100
# [139]	validation_0-rmse:39397.39496	validation_0-mean_squared_log_error:0.03079
# [140]	validation_0-rmse:39292.81740	validation_0-mean_squared_log_error:0.03069
# [141]	validation_0-rmse:39214.91055	validation_0-mean_squared_log_error:0.03060
# [142]	validation_0-rmse:39140.76823	validation_0-mean_squared_log_error:0.03054
# [143]	validation_0-rmse:38957.04812	validation_0-mean_squared_log_error:0.03020
# [144]	validation_0-rmse:38875.27535	validation_0-mean_squared_log_error:0.03005
# [145]	validation_0-rmse:38751.32475	validation_0-mean_squared_log_error:0.02989
# [146]	validation_0-rmse:38585.93935	validation_0-mean_squared_log_error:0.02960
# [147]	validation_0-rmse:38497.49863	validation_0-mean_squared_log_error:0.02951
# [148]	validation_0-rmse:38424.94136	validation_0-mean_squared_log_error:0.02946
# [149]	validation_0-rmse:38336.60831	validation_0-mean_squared_log_error:0.02938
# [150]	validation_0-rmse:38255.18738	validation_0-mean_squared_log_error:0.02930
# [151]	validation_0-rmse:38154.88200	validation_0-mean_squared_log_error:0.02919
# [152]	validation_0-rmse:38069.02149	validation_0-mean_squared_log_error:0.02908
# [153]	validation_0-rmse:38034.52993	validation_0-mean_squared_log_error:0.02907
# [154]	validation_0-rmse:37916.27143	validation_0-mean_squared_log_error:0.02887
# [155]	validation_0-rmse:37852.76109	validation_0-mean_squared_log_error:0.02883
# [156]	validation_0-rmse:37751.02138	validation_0-mean_squared_log_error:0.02863
# [157]	validation_0-rmse:37684.37696	validation_0-mean_squared_log_error:0.02858
# [158]	validation_0-rmse:37566.17973	validation_0-mean_squared_log_error:0.02838
# [159]	validation_0-rmse:37510.55324	validation_0-mean_squared_log_error:0.02830
# [160]	validation_0-rmse:37426.80467	validation_0-mean_squared_log_error:0.02819
# [161]	validation_0-rmse:37360.36155	validation_0-mean_squared_log_error:0.02816
# [162]	validation_0-rmse:37309.68663	validation_0-mean_squared_log_error:0.02814
# [163]	validation_0-rmse:37202.83697	validation_0-mean_squared_log_error:0.02797
# [164]	validation_0-rmse:37141.74475	validation_0-mean_squared_log_error:0.02792
# [165]	validation_0-rmse:37075.43216	validation_0-mean_squared_log_error:0.02781
# [166]	validation_0-rmse:37032.16534	validation_0-mean_squared_log_error:0.02777
# [167]	validation_0-rmse:36957.12228	validation_0-mean_squared_log_error:0.02765
# [168]	validation_0-rmse:36915.85962	validation_0-mean_squared_log_error:0.02762
# [169]	validation_0-rmse:36856.20465	validation_0-mean_squared_log_error:0.02756
# [170]	validation_0-rmse:36795.27044	validation_0-mean_squared_log_error:0.02747
# [171]	validation_0-rmse:36775.21771	validation_0-mean_squared_log_error:0.02747
# [172]	validation_0-rmse:36715.62764	validation_0-mean_squared_log_error:0.02738
# [173]	validation_0-rmse:36670.28517	validation_0-mean_squared_log_error:0.02728
# [174]	validation_0-rmse:36635.59405	validation_0-mean_squared_log_error:0.02726
# [175]	validation_0-rmse:36518.94563	validation_0-mean_squared_log_error:0.02706
# [176]	validation_0-rmse:36486.60225	validation_0-mean_squared_log_error:0.02704
# [177]	validation_0-rmse:36412.40839	validation_0-mean_squared_log_error:0.02698
# [178]	validation_0-rmse:36407.82132	validation_0-mean_squared_log_error:0.02700
# [179]	validation_0-rmse:36373.76218	validation_0-mean_squared_log_error:0.02696
# [180]	validation_0-rmse:36335.70344	validation_0-mean_squared_log_error:0.02693
# [181]	validation_0-rmse:36275.44676	validation_0-mean_squared_log_error:0.02689
# [182]	validation_0-rmse:36211.44687	validation_0-mean_squared_log_error:0.02682
# [183]	validation_0-rmse:36176.09847	validation_0-mean_squared_log_error:0.02679
# [184]	validation_0-rmse:36160.16219	validation_0-mean_squared_log_error:0.02681
# [185]	validation_0-rmse:36141.33093	validation_0-mean_squared_log_error:0.02684
# [186]	validation_0-rmse:36090.30214	validation_0-mean_squared_log_error:0.02679
# [187]	validation_0-rmse:36051.38625	validation_0-mean_squared_log_error:0.02675
# [188]	validation_0-rmse:36029.99987	validation_0-mean_squared_log_error:0.02670
# [189]	validation_0-rmse:35995.87783	validation_0-mean_squared_log_error:0.02668
# [190]	validation_0-rmse:35930.92360	validation_0-mean_squared_log_error:0.02661
# [191]	validation_0-rmse:35910.36524	validation_0-mean_squared_log_error:0.02667
# [192]	validation_0-rmse:35888.25358	validation_0-mean_squared_log_error:0.02673
# [193]	validation_0-rmse:35850.02919	validation_0-mean_squared_log_error:0.02675
# [194]	validation_0-rmse:35818.08766	validation_0-mean_squared_log_error:0.02672
# 0.13348353326897472

# %%
predictions = my_pipeline.predict(X_test)

def make_submission(predictions):
  predictions_df = pd.DataFrame(data={"Id": range(1461, 1461 + len(predictions)), "SalePrice": predictions})
  predictions_df.to_csv("submission.csv", index=False)

make_submission(predictions)
